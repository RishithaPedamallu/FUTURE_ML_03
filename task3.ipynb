# %%
import pandas as pd

# %%
data = {
    'resume': [
        "Python Java Machine Learning",
        "HTML CSS JavaScript",
        "Python Data Science AI",
        "Java Spring Boot Backend"
    ]
}

df = pd.DataFrame(data)
df
# Out:
#                          resume
# 0  Python Java Machine Learning
# 1           HTML CSS JavaScript
# 2        Python Data Science AI
# 3      Java Spring Boot Backend

# %%
job_description = "Python Machine Learning Data Science"

# %%
def score_resume(resume, job):
    resume_words = set(resume.lower().split())
    job_words = set(job.lower().split())
    
    score = len(resume_words.intersection(job_words))
    return score

df['score'] = df['resume'].apply(lambda x: score_resume(x, job_description))
df
# Out:
#                          resume  score
# 0  Python Java Machine Learning      3
# 1           HTML CSS JavaScript      0
# 2        Python Data Science AI      3
# 3      Java Spring Boot Backend      0

# %%
df = df.sort_values(by='score', ascending=False)
df
# Out:
#                          resume  score
# 0  Python Java Machine Learning      3
# 2        Python Data Science AI      3
# 1           HTML CSS JavaScript      0
# 3      Java Spring Boot Backend      0
